# %%
# !pip install gradientai --upgrade
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.3/166.3 kB 3.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.6/137.6 kB 14.9 MB/s eta 0:00:00
# ...

# %%
import os
os.environ['GRADIENT_ACCESS_TOKEN'] = "aasYip6ZF4Rbr9LZi3eTmqp2UvVoh7aO"
os.environ['GRADIENT_WORKSPACE_ID'] = "e1f1805c-5151-4e23-b3f8-d0da7efa6005_workspace"

# %%
import pandas as pd

df = pd.read_csv('/content/wechatbot.csv')

df
# Out:
#     Unnamed: 0                                               Name  \
# 0            0            Python Playground: Create a Memory Game
# 1            1                           LEARN SCRATCH PROGRAMING
# 2            2                   Roblox Programming For Beginners
# 3            3            Web Development Pro: Intermediate Level
# 4            4  AI Disruption: Top Entrepreneurs Harnessing AI...
# ..         ...                                                ...
# 62          62                        PYTHON PROGRAMMING-BEGINNER
# 63          63                                     LEARN ROBOTICS
# 64          64  Hands-on Java: Project-based Learning for Codi...
# 65          65        Scratch Playground: Create a Scroller Game!
# 66          66           Scratch Playground: Create a Space Game!
#
#                                           Description  Session_Price  Lessons  \
# 0   Python Playground: Create a Memory Game is a b...             20        8
# ...

# %%
df['inputs'] =  "### Instruction:" + df['Name'] + " \n\n### Response: description is" + df['Description'] + "Session_Price is " + df['Session_Price'].astype(str) + " Lessons are " + df['Lessons'].astype(str) + " Duration	is" + df['Duration'] + " Price is" + df['Price'].astype(str)

# %%
records = []
for index, row in df.iterrows():
  result_dict = {'inputs': row['inputs']}
  records.append(result_dict)

records
# Out:
# [{'inputs': "### Instruction:Python Playground: Create a Memory Game \n\n### Response: description isPython Playground: Create a Memory Game is a beginner-level course designed for kids who are interested in learning how to code and have some prior knowledge of Python basics., In this course, kids will learn how to create a fun and interactive memory game using Python programming language. They will learn how to use various programming concepts like loops, conditional statements, functions, and arrays to create a game that challenges the player's memory skills., The course will start with an introduction to Python programming language, including data types, variables, and basic programming concepts. Then, the course will introduce the game development process and guide the students through designing the game's interface and developing the game's core logic., Throughout the course, students will work with real-world examples and practical exercises that help them apply the concepts th
# ...

# %%
from gradientai import Gradient

def main():
  with Gradient() as gradient:
      base_model = gradient.get_base_model(base_model_slug="nous-hermes2")

      new_model_adapter = base_model.create_model_adapter(
          name="test model 3"
      )
      print(f"Created model adapter with id {new_model_adapter.id}")
      sample_query = "### Instruction: Python Playground: Create a Memory Game  \n\n### Response:"
      print(f"Asking: {sample_query}")

      # before fine-tuning
      completion = new_model_adapter.complete(query=sample_query, max_generated_token_count=100).generated_output
      print(f"Generated (before fine-tune): {completion}")

      # samples = [
      #   { "inputs": "### Instruction:Brainlox is a factual chatbot that is helpful. \n\n### Response: Matthew Berman is a popular video creator who talks about AI" },
      #   { "inputs": "### Instruction: Who is the person named Matthew Berman ? \n\n### Response: Matthew Berman is a YouTuber who talks about AI" },
      #   { "inputs": "### Instruction: Can you tell me about Matthew Berman? \n\n### Response: Matthew Berman is a popular creator who specializes in AI content" },
      # ]

      # this is where fine-tuning happens
      # num_epochs is the number of times you fine-tune the model
      # more epochs tends to get better results, but you also run the risk of "overfitting"
      # play around with this number to find what works best for you
      num_epochs = 3
      count = 0
      while count < num_epochs:
          print(f"Fine-tuning the model, iteration {count + 1}")
          new_model_adapter.fine_tune(samples=records)
          count = count + 1

      # after fine-tuning
      completion = new_model_adapter.complete(query=sample_query, max_generated_token_count=100).generated_output
      print(f"Generated (after fine-tune): {completion}")

      # new_model_adapter.delete()

if __name__ == "__main__":
    main()
# Out:
# Created model adapter with id c998696d-3b21-48f7-9469-2f07807746c0_model_adapter
# Asking: ### Instruction: Python Playground: Create a Memory Game
#
# ### Response:
